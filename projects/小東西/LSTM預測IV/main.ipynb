# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

NOTE_PATH = next(
    (
        root / "note"
        for root in (Path.cwd(), *Path.cwd().parents)
        if (root / "note" / "module" / "get_info_FinMind.py").exists()
    ),
    Path("/Users/xinc/GitHub/note"),
)
sys.path.insert(0, str(NOTE_PATH))

from module.get_info_FinMind import FinMindClient

# %%
fm = FinMindClient()

manifest = fm.download_option_tick_to_parquet(
    output_dir="data/TaiwanOptionTick",
    option_id="TXO",
    start_date="2021-01-01",
    end_date="2021-01-31",
)
# Out:
# 2026-05-29 10:04:26.138 | INFO     | FinMind.data.finmind_api:login_by_token:84 - Login success
# 2026-05-29 10:04:26.221 | INFO     | FinMind.data.finmind_api:login_by_token:84 - Login success
# Downloading TaiwanOptionTick:   0%|          | 0/1304 [00:00<?, ?it/s]2026-05-29 10:04:26.245 | INFO     | FinMind.data.finmind_api:get_data:153 - download Dataset.TaiwanOptionTick, data_id: TXO
# Downloading TaiwanOptionTick:   0%|          | 1/1304 [00:00<15:02,  1.44it/s]2026-05-29 10:04:26.936 | INFO     | FinMind.data.finmind_api:get_data:153 - download Dataset.TaiwanOptionTick, data_id: TXO
# Downloading TaiwanOptionTick:   0%|          | 2/1304 [00:05<1:11:57,  3.32s/it]2026-05-29 10:04:32.089 | INFO     | FinMind.data.finmind_api:get_data:153 - download Dataset.TaiwanOptionTick, data_id: TXO
# Downloading TaiwanOptionTick:   0%|          | 3/1304 [00:10<1:25:12,  3.93s/it]2026-05-29 10:04:36.750 | INFO     | FinMind.data.finmind_api:get_data:153 - download Dataset.TaiwanOptionTick, data_id: TXO
# Downloading TaiwanOptionTick:   0%|          | 3/1304 [00:11<1:23:01,  3.83s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 fm = FinMindClient()
# ----> 3 df = fm.get_option_tick_range(
#       4     option_id="TXO",
#       5     start_date="2021-01-01",
#       6     end_date="2025-12-31",
#       7 )
#
# File ~/GitHub/note/module/get_info_FinMind.py:632, in FinMindClient.get_option_tick_range(self, option_id, start_date, end_date, option_id_list, business_days_only, use_async, timeout, params, show_progress)
#     630 for trade_date in iterator:
#     631     try:
# --> 632         data = self.get_option_tick(
#     633             option_id=option_id,
#     634             trade_date=trade_date,
#     635             option_id_list=option_id_list,
#     636             use_async=use_async,
#     637             timeout=timeout,
#     638             params=params,
#     639         )
#     640     except Exception as exc:
#     641         if show_progress:
#
# File ~/GitHub/note/module/get_info_FinMind.py:586, in FinMindClient.get_option_tick(self, option_id, trade_date, option_id_list, use_async, timeout, params)
#     583     else:
#     584         kwargs["option_id"] = option_id
# --> 586     data = self.taiwan_option_tick(**kwargs)
#     587 else:
#     588     data = self.get_data(
#     589         dataset="TaiwanOptionTick",
#     590         data_id=option_id,
#    (...)    593         **request_params,
#     594     )
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/site-packages/FinMind/data/data_loader.py:1173, in DataLoader.taiwan_option_tick(self, option_id, date, timeout, use_async, option_id_list)
#    1150 def taiwan_option_tick(
#    1151     self,
#    1152     option_id: str,
#    (...)   1156     option_id_list: typing.List[str] = None,
#    1157 ) -> pd.DataFrame:
#    1158     """get 選擇權交易明細表, 資料量超過10萬筆, 需等一段時間
#    1159     :param option_id: 選擇權代號("TXO")
#    1160     :param date (str): 日期("2018-01-01")
#    (...)   1171     :rtype column volume (int)
#    1172     """
# -> 1173     option_tick = self.get_data(
#    1174         dataset=Dataset.TaiwanOptionTick,
#    1175         data_id=option_id,
#    1176         start_date=date,
#    1177         timeout=timeout,
#    1178         use_async=use_async,
#    1179         data_id_list=option_id_list,
#    1180     )
#    1181     return option_tick
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/site-packages/FinMind/data/finmind_api.py:169, in FinMindApi.get_data(self, dataset, data_id, securities_trader_id, stock_id, start_date, data_id_list, securities_trader_id_list, end_date, timeout, use_async, max_retry_times)
#     167 url = self._dispatcher_url(dataset)
#     168 logger.debug(params)
# --> 169 response = request_get(
#     170     self.__session,
#     171     url,
#     172     params=params,
#     173     timeout=timeout,
#     174 ).json()
#     175 return pd.DataFrame(response["data"])
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/site-packages/FinMind/utility/request.py:30, in request_get(session, url, params, timeout, max_retry_times, verbose)
#      28 for retry_times in range(1, max_retry_times + 1):
#      29     try:
# ---> 30         response = session.get(
#      31             url,
#      32             verify=True,
#      33             params=params,
#      34             timeout=timeout,
#      35         )
#      36         if response.status_code == 504:
#      37             if verbose:
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/site-packages/urllib3/response.py:1257, in HTTPResponse.stream(self, amt, decode_content)
#    1251 else:
#    1252     while (
#    1253         not is_fp_closed(self._fp)
#    1254         or len(self._decoded_buffer) > 0
#    1255         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1256     ):
# -> 1257         data = self.read(amt=amt, decode_content=decode_content)
#    1259         if data:
#    1260             yield data
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/site-packages/urllib3/response.py:1112, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1109     if len(self._decoded_buffer) >= amt:
#    1110         return self._decoded_buffer.get(amt)
# -> 1112 data = self._raw_read(amt)
#    1114 flush_decoder = amt is None or (amt != 0 and not data)
#    1116 if (
#    1117     not data
#    1118     and len(self._decoded_buffer) == 0
#    1119     and not (self._decoder and self._decoder.has_unconsumed_tail)
#    1120 ):
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/site-packages/urllib3/response.py:1028, in HTTPResponse._raw_read(self, amt, read1)
#    1025 fp_closed = getattr(self._fp, "closed", False)
#    1027 with self._error_catcher():
# -> 1028     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#    1029     if amt is not None and amt != 0 and not data:
#    1030         # Platform-specific: Buggy versions of Python.
#    1031         # Close the connection when no data is returned
#    (...)   1036         # not properly close the connection in all cases. There is
#    1037         # no harm in redundantly calling close.
#    1038         self._fp.close()
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/site-packages/urllib3/response.py:1011, in HTTPResponse._fp_read(self, amt, read1)
#    1008     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#    1009 else:
#    1010     # StringIO doesn't like amt=None
# -> 1011     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/http/client.py:484, in HTTPResponse.read(self, amt)
#     481 if self.length is not None and amt > self.length:
#     482     # clip the read to the "end of response"
#     483     amt = self.length
# --> 484 s = self.fp.read(amt)
#     485 if not s and amt:
#     486     # Ideally, we would raise IncompleteRead if the content-length
#     487     # wasn't satisfied, but it might break compatibility.
#     488     self._close_conn()
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/envs/quant_mac/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df
# Out:
#         ExercisePrice PutCall contract_date                date option_id  \
# 0             22800.0       P        202501 2025-01-10 00:00:13       TXO
# 1             22800.0       P        202501 2025-01-10 00:00:13       TXO
# 2             23600.0       C        202501 2025-01-10 00:00:14       TXO
# 3             23600.0       C        202501 2025-01-10 00:00:14       TXO
# 4             23200.0       C        202501 2025-01-10 00:00:15       TXO
# ...               ...     ...           ...                 ...       ...
# 482247        22450.0       P        202501 2025-01-10 23:59:59       TXO
# 482248        22450.0       P        202501 2025-01-10 23:59:59       TXO
# 482249        23300.0       C        202501 2025-01-10 23:59:59       TXO
# 482250        22450.0       P        202501 2025-01-10 23:59:59       TXO
# 482251        23300.0       C        202501 2025-01-10 23:59:59       TXO
#
#         price  volume
# 0        81.0       1
# 1        81.0       1
# 2        46.0       1
# 3        46.0       1
# 4       175.0       1
# ...       ...     ...
# 482247   49.0       2
# 482248   49.0       4
# 482249   49.0       1
# 482250   49.5      10
# 482251   49.0       1
#
# [482252 rows x 7 columns]
