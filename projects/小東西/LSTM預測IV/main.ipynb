# %%
# Quant data policy: this repo reads Google Drive data; downloads run from note.
import sys
from pathlib import Path
_QUANT_ROOT = Path("/Users/xinc/GitHub/Quant")
if str(_QUANT_ROOT) not in sys.path:
    sys.path.insert(0, str(_QUANT_ROOT))
import cloud_data

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys
import pandas as pd

QUANT_PATH = Path("/Users/xinc/GitHub/Quant")
if str(QUANT_PATH) not in sys.path:
    sys.path.insert(0, str(QUANT_PATH))

from cloud_data import TW_OPTIONS_TICK

tick_files = sorted((TW_OPTIONS_TICK / "TXO").glob("*/*.parquet"))
manifest = pd.DataFrame({"path": tick_files})
manifest["date"] = pd.to_datetime(manifest["path"].map(lambda path: path.stem))
manifest.sort_values("date").reset_index(drop=True)

# %%
manifest = fm.download_option_tick_to_parquet(
    output_dir=TW_OPTIONS_TICK,
    option_id="TXO",
    start_date="2021-01-01",
    end_date="2025-01-31",
)
# Out:
# Saving TaiwanOptionTick TXO:   2%|▏         | 23/1066 [03:03<2:34:09,  8.87s/it]
# TaiwanOptionTick 2021-02-02 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:   5%|▌         | 54/1066 [05:28<1:39:44,  5.91s/it]
# TaiwanOptionTick 2021-03-17 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:   9%|▊         | 93/1066 [10:35<7:04:36, 26.18s/it]
# TaiwanOptionTick 2021-05-11 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  13%|█▎        | 139/1066 [16:09<1:41:34,  6.57s/it]
# TaiwanOptionTick 2021-07-14 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  13%|█▎        | 143/1066 [16:30<1:21:58,  5.33s/it]
# TaiwanOptionTick 2021-07-20 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  29%|██▉       | 314/1066 [34:42<2:11:57, 10.53s/it]
# TaiwanOptionTick 2022-03-16 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  48%|████▊     | 516/1066 [56:53<45:42,  4.99s/it]
# TaiwanOptionTick 2022-12-23 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  62%|██████▏   | 664/1066 [1:09:23<42:02,  6.27s/it]
# TaiwanOptionTick 2023-07-19 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  63%|██████▎   | 674/1066 [1:10:28<41:56,  6.42s/it]
# TaiwanOptionTick 2023-08-02 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  65%|██████▌   | 694/1066 [1:12:49<39:21,  6.35s/it]
# TaiwanOptionTick 2023-08-30 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  68%|██████▊   | 724/1066 [1:15:26<15:43,  2.76s/it]
# TaiwanOptionTick 2023-10-11 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  69%|██████▊   | 731/1066 [1:16:05<26:53,  4.82s/it]
# TaiwanOptionTick 2023-10-20 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  78%|███████▊  | 833/1066 [1:25:00<30:30,  7.86s/it]
# TaiwanOptionTick 2024-03-12 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  80%|████████  | 853/1066 [1:27:20<14:40,  4.13s/it]
# TaiwanOptionTick 2024-04-09 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  83%|████████▎ | 884/1066 [1:31:14<17:44,  5.85s/it]
# TaiwanOptionTick 2024-05-22 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  83%|████████▎ | 886/1066 [1:31:24<15:59,  5.33s/it]
# TaiwanOptionTick 2024-05-24 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  84%|████████▍ | 893/1066 [1:32:16<19:43,  6.84s/it]
# TaiwanOptionTick 2024-06-04 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  84%|████████▍ | 894/1066 [1:32:27<23:29,  8.20s/it]
# TaiwanOptionTick 2024-06-05 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  93%|█████████▎| 988/1066 [1:44:28<08:20,  6.42s/it]
# TaiwanOptionTick 2024-10-15 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO:  98%|█████████▊| 1047/1066 [1:51:14<01:52,  5.93s/it]
# TaiwanOptionTick 2025-01-06 failed: Expecting value: line 1 column 1 (char 0)
# Saving TaiwanOptionTick TXO: 100%|██████████| 1066/1066 [1:52:50<00:00,  6.35s/it]

# %%
base = TW_OPTIONS_TICK / "TXO"
records = []
for date in failed_dates:
    path = base / date[:4] / f"{date}.parquet"
    records.append({
        "date": date,
        "status": "available" if path.exists() else "missing",
        "path": path,
    })

retry_manifest = pd.DataFrame(records)
display(retry_manifest)
print(
    "Missing tick files must be updated from note with: "
    "python scripts/data_updates/update_txo_ticks.py"
)
